# %% [markdown]
# # Fun with frequencies: More counting & tabulating

# %%
# configure; define some constants
CARREL   = 'homer'
TEMPLATE = './carrels/%s/etc/reader.txt'
LANGUAGE = 'english'
KEYWORDS = [ 'love', 'war', 'man', 'woman', 'god' ]

# %%
# require
from nltk import *
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# initilize
stopwords = set( corpus.stopwords.words( LANGUAGE ) )

# %%
# read the given file, tokenize its words, and normalize them
file   = TEMPLATE % CARREL
data   = open( file ).read()
tokens = word_tokenize( data )
tokens = [ token.lower() for token in tokens if token.isalpha() ]
tokens = [ token for token in tokens if token not in stopwords ]

# %%
# count & tabulate each token
frequencies = FreqDist( tokens )

# %%
# output the most frequent N tokens
N = 5
frequencies.most_common( N )
# Out:
# [('son', 1276), ('one', 982), ('said', 885), ('upon', 795), ('man', 765)]

# %%
# output an alphabetical list of words appearing only once
sorted( frequencies.hapaxes() )
# Out:
# ['abarbarea',
#  'abas',
#  'abate',
#  'abated',
#  'abetting',
#  'abians',
#  'abiding',
#  'ablerus',
#  'aboard',
#  'abodes',
#  'abominably',
#  'absolutely',
#  'absurd',
#  'abundantly',
#  'abusing',
#  'acastus',
#  'acceptance',
#  'accepted',
#  'accident',
#  'accompaniment',
#  'accomplish',
#  'accomplishment',
#  'accounting',
#  'accounts',
#  'accursed',
#  'accusing',
#  'acessamenus',
#  'achaea',
#  'ache',
#  'acheron',
#  'aching',
#  'acknowledge',
#  'acorns',
#  'acquaintance',
#  'acre',
#  'acrisius',
#  'acroneos',
#  'actaea',
#  'acting',
#  'addition',
#  'additional',
#  'addresses',
#  'admiring',
#  'admiringly',
#  'admit',
#  'admittance',
#  'adored',
#  'adorn',
#  'adorning',
#  'adraste',
#  'adresteia',
#  'advised',
#  'adze',
#  'adzed',
#  'aegaeon',
#  'aegeus',
#  'aegialeia',
#  'aegialus',
#  'aegilips',
#  'aegina',
#  'aegium',
#  'aenus',
#  'aepytus',
#  'aeson',
#  'aesyme',
#  'aesymnus',
#  'aetes',
#  'aethrae',
#  'affair',
#  'affection',
#  'affectionate',
#  'afflicts',
#  'affrighted',
#  'afternoon',
#  'agacles',
#  'agamede',
#  'agapenor',
#  'agasthenes',
#  'agathon',
#  'agave',
#  'ageless',
#  'aglow',
#  'agonies',
#  'agree',
#  'agreeable',
#  'agrius',
#  'aiding',
#  'aimlessly',
#  'aipy',
#  'airs',
#  'aithices',
#  'alcandra',
#  'alcandrus',
#  'alcestis',
#  'alcippe',
#  'alcmaeon',
#  'alcyone',
#  'alean',
#  'alector',
#  'alectryon',
#  'alegenor',
#  'alesium',
#  'alexandria',
#  'alight',
#  'alighting',
#  'alision',
#  'allotment',
#  'allotting',
#  'allowance',
#  'allowances',
#  'allows',
#  'alope',
#  'alos',
#  'alternatives',
#  'althaea',
#  'alybas',
#  'alybe',
#  'amarynces',
#  'amassed',
#  'amatheia',
#  'amazement',
#  'amisodorus',
#  'amity',
#  'amnisus',
#  'amopaon',
#  'amphiclus',
#  'amphigenea',
#  'amphilochus',
#  'amphinome',
#  'amphithea',
#  'amphithoe',
#  'amphoterus',
#  'amply',
#  'amyclae',
#  'amythaon',
#  'anabesineus',
#  'ancestors',
#  'ancestral',
#  'anchor',
#  'anchors',
#  'ancled',
#  'anemorea',
#  'angle',
#  'annoyed',
#  'answers',
#  'antagonist',
#  'antea',
#  'anthedon',
#  'anticlea',
#  'antiope',
#  'antiphonus',
#  'antlered',
#  'antrum',
#  'anvils',
#  'apace',
#  'apaesus',
#  'apheidas',
#  'apiece',
#  'apothecaries',
#  'appalling',
#  'apparel',
#  'appeal',
#  'appears',
#  'applied',
#  'appointed',
#  'apprehend',
#  'approve',
#  'apseudes',
#  'apt',
#  'aptitude',
#  'araethyrea',
#  'arcades',
#  'arcadia',
#  'archilochus',
#  'aretaon',
#  'arethusa',
#  'argeas',
#  'argissa',
#  'argo',
#  'argument',
#  'arimi',
#  'arion',
#  'arisbas',
#  'armfuls',
#  'armies',
#  'armlets',
#  'arnaeus',
#  'arose',
#  'arrived',
#  'arsinous',
#  'artacia',
#  'artful',
#  'artifice',
#  'artificers',
#  'artisans',
#  'arybas',
#  'asaeus',
#  'ascend',
#  'asine',
#  'aslant',
#  'asopus',
#  'aspect',
#  'aspen',
#  'asphalion',
#  'aspledon',
#  'assailants',
#  'assailed',
#  'assailing',
#  'assent',
#  'assist',
#  'assure',
#  'assures',
#  'asteris',
#  'asterius',
#  'astonish',
#  'astray',
#  'astyalus',
#  'astyoche',
#  'astyochea',
#  'astypylus',
#  'athenian',
#  'athlete',
#  'athos',
#  'atmosphere',
#  'atrociously',
#  'attempted',
#  'attire',
#  'attiring',
#  'auger',
#  'augers',
#  'aught',
#  'augury',
#  'aurora',
#  'autonoe',
#  'avengers',
#  'avert',
#  'avowed',
#  'awaited',
#  'awakes',
#  'awards',
#  'aware',
#  'awed',
#  'awhile',
#  'axylus',
#  'azeus',
#  'babe',
#  'babel',
#  'backbone',
#  'backbones',
#  'backing',
#  'backs',
#  'backstay',
#  'bait',
#  'baldrics',
#  'ballooing',
#  'baned',
#  'banes',
#  'baning',
#  'banish',
#  'banishes',
#  'banqueting',
#  'barbarous',
#  'bargaining',
#  'baring',
#  'barque',
#  'barred',
#  'barrier',
#  'bask',
#  'bat',
#  'bate',
#  'bathe',
#  'bathed',
#  'batieia',
#  'bats',
#  'battled',
#  'battledore',
#  'bawling',
#  'beak',
#  'beaks',
#  'beaming',
#  'beans',
#  'beauteous',
#  'beauties',
#  'beautified',
#  'becalmed',
#  'beck',
#  'beckoned',
#  'bedchamber',
#  'bedded',
#  'bedside',
#  'bedsteads',
#  'beechmast',
#  'befitting',
#  'beforehand',
#  'befriended',
#  'beggarly',
#  'begone',
#  'beguiles',
#  'behaviour',
#  'behead',
#  'beholding',
#  'behooves',
#  'beleaguered',
#  'beleaguering',
#  'believes',
#  'belong',
#  'belonged',
#  'bench',
#  'bends',
#  'beseeching',
#  'besiegers',
#  'bespatter',
#  'bessa',
#  'bestirred',
#  'bestrewn',
#  'bestriding',
#  'bestudded',
#  'betide',
#  'betwixt',
#  'bevy',
#  'bewail',
#  'bewailing',
#  'bewildered',
#  'bewitched',
#  'bibber',
#  'bided',
#  'bienor',
#  'biggest',
#  'billet',
#  'bitch',
#  'bitterest',
#  'bivouac',
#  'blacksmith',
#  'blades',
#  'blamed',
#  'blaming',
#  'blandishment',
#  'blare',
#  'blazes',
#  'bleached',
#  'blear',
#  'bleared',
#  'bleat',
#  'bleeds',
#  'blessing',
#  'blighting',
#  'blinding',
#  'blindly',
#  'blindness',
#  'blithe',
#  'bloodless',
#  'bloodlessly',
#  'bloodshed',
#  'blossom',
#  'blotted',
#  'blown',
#  'boagrius',
#  'boarhounds',
#  'boatmen',
#  'bode',
#  'boding',
#  'boebe',
#  'boebean',
#  'boethous',
#  'boil',
#  'boiled',
#  'bolder',
#  'boldest',
#  'bolting',
#  'bondman',
#  'bondsman',
#  'bondswomen',
#  'bondwoman',
#  'boons',
#  'bootes',
#  'boots',
#  'border',
#  'boring',
#  'boucolos',
#  'boundaries',
#  'boundary',
#  'boundless',
#  'bounty',
#  'bout',
#  'bowmen',
#  'bowstrings',
#  'boxwood',
#  'boyish',
#  'braces',
#  'brambles',
#  'branching',
#  'brand',
#  'branded',
#  'brandish',
#  'brandishes',
#  'braver',
#  'braves',
#  'breastpiece',
#  'breastworks',
#  'breathes',
#  'breathless',
#  'breeder',
#  'breeders',
#  'breezes',
#  'breezy',
#  'briareus',
#  'bribed',
#  'bribes',
#  'bridging',
#  'briefly',
#  'brightest',
#  'briskly',
#  'bristled',
#  'broach',
#  'bronzed',
#  'brooches',
#  'bruise',
#  'bruises',
#  'brutally',
#  'bryseae',
#  'bubbled',
#  'bucket',
#  'buckled',
#  'bucklers',
#  'buckles',
#  'bud',
#  'budeum',
#  'buds',
#  'buffeting',
#  'builders',
#  'bully',
#  'bulwarks',
#  'bunched',
#  'bunches',
#  'buoy',
#  'burdened',
#  'burying',
#  'bushes',
#  'busily',
#  'bustled',
#  'busying',
#  'butcher',
#  'butchered',
#  'butcheries',
#  'butchering',
#  'buttresses',
#  'butts',
#  'byblus',
#  'bystanders',
#  'cabesus',
#  'cadmeians',
#  'cajoling',
#  'cakes',
#  'calamities',
#  'calamity',
#  'calesius',
#  'calf',
#  'callianassa',
#  'callianeira',
#  'calliarus',
#  'calmed',
#  'calmer',
#  'calydnian',
#  'cameirus',
#  'camps',
#  'canopy',
#  'capable',
#  'capture',
#  'capturing',
#  'carcases',
#  'carding',
#  'career',
#  'carelessly',
#  'caressing',
#  'caresus',
#  'cargoes',
#  'caria',
#  'caring',
#  'carved',
#  'carvers',
#  'carystus',
#  'cases',
#  'casque',
#  'castianeira',
#  'casus',
#  'cataract',
#  'caves',
#  'cayster',
#  'cedar',
#  'ceiling',
#  'celadon',
#  'celery',
#  'cell',
#  'centaur',
#  'centre',
#  'ceos',
#  'cephisian',
#  'cerinthus',
#  'certainty',
#  'certify',
#  'ceteians',
#  'chafe',
#  'chalcon',
#  'challenger',
#  'challenges',
#  'chamois',
#  'chances',
#  'changes',
#  'charges',
#  'charioteers',
#  'charis',
#  'charlatan',
#  'charming',
#  'charops',
#  'charred',
#  'charring',
#  'chattel',
#  'chatter',
#  'chattered',
#  'chaunted',
#  'chaunting',
#  'cheaper',
#  'checks',
#  'cheeping',
#  'cheerfulness',
#  'cheeringly',
#  'cheers',
#  'cherished',
#  'chersidamas',
#  'chestnut',
#  'chickens',
#  'childbirth',
#  'childish',
#  'chimneys',
#  'chine',
#  'chirrup',
#  'chivalry',
#  'chloris',
#  'choked',
#  'choking',
#  'choosing',
#  'chop',
#  'chromis',
#  'chuckle',
#  'churl',
#  'cicales',
#  'ciconian',
#  'cimmerians',
#  'cinyras',
#  'circled',
#  'circling',
#  'circuit',
#  'cisseus',
#  'civil',
#  'claimed',
#  'clamoured',
#  'clamouring',
#  'clank',
#  'clanless',
#  'clapping',
#  'clarion',
#  'clatter',
#  'clattered',
#  'clattering',
#  'claws',
#  'clay',
#  'cleaned',
#  'cleaning',
#  'cleanses',
#  'cleared',
#  'clearly',
#  'clears',
#  'cleaver',
#  'cleaves',
#  'cleft',
#  'cleobulus',
#  'cleonae',
#  'cling',
#  'clip',
#  'cloths',
#  'clouts',
#  'clubbed',
#  'clubfooted',
#  'cluster',
#  'clusters',
#  'clutch',
#  'clymenus',
#  'clytomedes',
#  'coarse',
#  'coasts',
#  'coated',
#  'cocytus',
#  'coeranus',
#  'coherent',
#  'coils',
#  'colder',
#  'collect',
#  'colonised',
#  'colonnades',
#  'coloured',
#  'colours',
#  'comeliest',
#  'comforter',
#  'comforting',
#  'comfortingly',
#  'comings',
#  'commend',
#  'commission',
#  'commits',
#  'committing',
#  'commune',
#  'compact',
#  'compassing',
#  'compassionately',
#  'compel',
#  'compelling',
#  'competed',
#  'competing',
#  'competitions',
#  'competitors',
#  'complaints',
#  'completely',
#  'complexion',
#  'compliment',
#  'compose',
#  'conceal',
#  'concede',
#  'conceivable',
#  'concern',
#  'concerned',
#  'concerns',
#  'concert',
#  'conciliate',
#  'conclude',
#  'concludes',
#  'concourse',
#  'conditioned',
#  'confirmation',
#  'conflict',
#  'confused',
#  'congratulated',
#  'conjecture',
#  'connected',
#  'conquer',
#  'conquering',
#  'conscience',
#  'consciences',
#  'constancy',
#  'consulted',
#  'consulting',
#  'containing',
#  'continents',
#  'continuing',
#  'continuous',
#  'contribute',
#  'control',
#  'convene',
#  'conversant',
#  'conversations',
#  'conversing',
#  'convey',
#  'convince',
#  'convinced',
#  'convulsed',
#  'cool',
#  'cooling',
#  'copae',
#  'coppers',
#  'coppice',
#  'copreus',
#  'cormorant',
#  'cornel',
#  'cornice',
#  'coronea',
#  'coronus',
#  'corruption',
#  'costs',
#  'couches',
#  'councillor',
#  'couples',
#  'courageous',
#  'courteous',
#  'cousin',
#  'cousins',
#  'coverings',
#  'covertly',
#  'covetous',
#  'cowed',
#  'coxswain',
#  'cozen',
#  'crack',
#  'cracking',
#  'craftiest',
#  'crag',
#  'cramped',
#  'cranae',
#  'crapathus',
#  'crataiis',
#  'cravings',
#  'crawled',
#  'crazed',
#  'creek',
#  'creion',
#  'creon',
#  'creontes',
#  'crimes',
#  'crisa',
#  'crocus',
#  'crocylea',
#  'croesmus',
#  'cromna',
#  'crop',
#  'crossbeams',
#  'crosspiece',
#  'crouches',
#  'crouni',
#  'crown',
#  'cruelly',
#  'crunch',
#  'crunching',
#  'crushes',
#  'ctesius',
#  'cur',
#  'curdled',
#  'curdles',
#  'curing',
#  'curiosity',
#  'curiously',
#  'curling',
#  'curly',
#  'curse',
#  'cursed',
#  'curtain',
#  'curvetted',
#  'cushion',
#  'customary',
#  'customs',
#  'cydonians',
#  'cymindis',
#  'cymodoce',
#  'cymothoe',
#  'cynus',
#  'cyparisseis',
#  'cyparissus',
#  'cyphus',
#  'cypress',
#  'cythereans',
#  'cytorus',
#  'daedalus',
#  'daetor',
#  'dagger',
#  'daggers',
#  'daintiest',
#  'dairy',
#  'dale',
#  'dales',
#  'dally',
#  'damage',
#  'damaged',
#  'damask',
#  'damasus',
#  'damming',
#  'damp',
#  'dams',
#  'damsel',
#  'danae',
#  'dances',
#  'dandled',
#  'dangerously',
#  'dangling',
#  'dardania',
#  'dashing',
#  'daulis',
#  'dawdle',
#  'dawning',
#  'deadened',
#  'deafening',
#  'dearth',
#  'deathlike',
#  'deaths',
#  'debts',
#  'deceit',
#  'deceitful',
#  'deceived',
#  'decency',
#  'decently',
#  'decides',
#  'decision',
#  'decks',
#  'decline',
#  'decoyed',
#  'deepened',
#  'deeper',
#  'deepest',
#  'defeat',
#  'defeated',
#  'defenceless',
#  'defenders',
#  'defer',
#  'deficient',
#  'defile',
#  'defiled',
#  'defraud',
#  'defy',
#  'defying',
#  'deicoon',
#  'deiochus',
#  'deiopites',
#  'deipylus',
#  'deisenor',
#  'deities',
#  'dejected',
#  'delicacy',
#  'delivery',
#  'delled',
#  'dells',
#  'delos',
#  'deluged',
#  'demesne',
#  'demigods',
#  'democoon',
#  'demoleon',
#  'demouchus',
#  'departing',
#  'depended',
#  'depends',
#  'deplore',
#  'depreciate',
#  'depth',
#  'descend',
#  'descendants',
#  'designs',
#  'desist',
#  'despairing',
#  'despatch',
#  'despatched',
#  'desperate',
#  'despiteful',
#  'despoiled',
#  'destitute',
#  'destroys',
#  'destructive',
#  'detailed',
#  'detain',
#  'detested',
#  'device',
#  'devote',
#  'devours',
#  'dexamene',
#  'dexius',
#  'dia',
#  'dice',
#  'differently',
#  'dignity',
#  'dim',
#  'dined',
#  'dingle',
#  'diomede',
#  'diplomacy',
#  'dipping',
#  'dips',
#  'directed',
#  'disaffection',
#  'disallow',
#  'disastrous',
#  'discernment',
#  'discharge',
#  'discomfits',
#  'disconcerted',
#  'discreditable',
#  'discreet',
#  'discuss',
#  'disdaining',
#  'disfigure',
#  'disfiguring',
#  'disgracefully',
#  'disguise',
#  'disguising',
#  'disgust',
#  'disgusted',
#  'dish',
#  'disheartened',
#  'disinclined',
#  'disloyal',
#  'disobeys',
#  'disorder',
#  'disparaging',
#  'dispensation',
#  'dispenser',
#  'dispensers',
#  'disperse',
#  'display',
#  'displayed',
#  'disposal',
#  'disposer',
#  'dispute',
#  'disputes',
#  'disquietness',
#  'disreputable',
#  'disrespect',
#  'disrespectful',
#  'disrespectfully',
#  'dissipated',
#  'dissuade',
#  'dissuaded',
#  'distinguish',
#  'distinguished',
#  'distraction',
#  'distressing',
#  'distribute',
#  'dium',
#  'dius',
#  'dive',
#  'diverse',
#  'diverting',
#  'dives',
#  'diviner',
#  'divines',
#  'dizzy',
#  'dmetor',
#  'doe',
#  'doer',
#  'dogfish',
#  'dolopians',
#  'dolopion',
#  'dolphin',
#  'dolphins',
#  'donors',
#  'dorians',
#  'doris',
#  'dorium',
#  'doryclus',
#  'doting',
#  'doto',
#  'doubled',
#  'doubling',
#  'doubtless',
#  'downstairs',
#  'downward',
#  'dowry',
#  'dracius',
#  'draft',
#  'drafting',
#  'dragon',
#  'drain',
#  'draughts',
#  'dreadfully',
#  'dreamed',
#  'dreamland',
#  'drenching',
#  'dresser',
#  'dresses',
#  'dresus',
#  'dries',
#  'drift',
#  'drip',
#  'drooped',
#  'drooping',
#  'dropping',
#  'drown',
#  'drowning',
#  'drowsiness',
#  'drowsy',
#  'drubbing',
#  'drunkard',
#  'drunken',
#  'dryops',
#  'duck',
#  'ducts',
#  'dudgeon',
#  'dupe',
#  'dusky',
#  'dweller',
#  'dye',
#  'dykes',
#  'dynamene',
#  'eagerly',
#  'earnings',
#  'eater',
#  'eats',
#  'echecles',
#  'echemmon',
#  'echinean',
#  'eclipse',
#  'eeriboea',
#  'effaced',
#  'effecting',
#  'effrontery',
#  'egging',
#  'eilesium',
#  'eilithuiae',
#  'eionae',
#  'elasus',
#  'elbows',
#  'elect',
#  'elone',
#  'elysian',
#  'elysium',
#  'emathia',
#  'embank',
#  ...]

# %%
# plot the frequency of N most frequent words
N = 10
frequencies.plot( N )
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# re-create the list of tokens to include only the keywords, count them, and plot them
tokens = [ token for token in tokens if token in KEYWORDS ] 
frequencies = FreqDist( tokens )
frequencies.plot()
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# read the given file, tokenize its words, and normalize them
data        = open( file ).read()
tokens      = word_tokenize( data )
tokens      = [ token.lower() for token in tokens if token.isalpha() ]
tokens      = [ token for token in tokens if token not in stopwords ] 
frequencies = FreqDist( tokens ).values()

# %%
# calculate mean (average), variance, and standard deviation
mean        = sum( frequencies ) / len( frequencies )
variance    = sum( ( frequency-mean )**2 for frequency in frequencies ) / len(frequencies)
deviation   = variance**0.5
print( "mean: %f; variance: %f; deviation: %f" % ( mean, variance, deviation ) )
# Out:
# mean: 12.848838; variance: 2242.904092; deviation: 47.359308

# %%
# create a list of second-teir "interesting" words

# initialize
frequencies = FreqDist( tokens )
n           = round( mean + deviation )
interesting = {}

# loop through each token in the frequencies
for token in frequencies :

        # parse
        count = frequencies[ token ]
        
        # update, optionally
        if ( mean <= count <= n ) : interesting[ token ] = count

# output
print( interesting )
# Out:
# {'vulcan': 60, 'glory': 60, 'taking': 60, 'valiant': 60, 'cattle': 60, 'mountain': 60, 'replied': 60, 'waters': 59, 'bound': 59, 'ready': 59, 'swineherd': 59, 'antinous': 59, 'sure': 58, 'fury': 58, 'deep': 57, 'call': 57, 'carried': 57, 'fine': 57, 'lost': 56, 'hither': 56, 'everything': 56, 'dogs': 56, 'neck': 56, 'word': 56, 'master': 56, 'court': 56, 'mortal': 55, 'escape': 55, 'fierce': 55, 'evil': 55, 'fought': 55, 'loud': 54, 'force': 54, 'wound': 54, 'present': 54, 'laertes': 54, 'tent': 54, 'sail': 54, 'phaeacians': 54, 'beat': 53, 'hero': 53, 'heroes': 53, 'lion': 53, 'killing': 53, 'meat': 53, 'pray': 53, 'ill': 53, 'followed': 52, 'immortals': 52, 'forth': 52, 'born': 52, 'thereon': 52, 'offered': 52, 'sacrifice': 52, 'talk': 52, 'pylos': 52, 'trouble': 52, 'hide': 51, 'hope': 51, 'peace': 51, 'used': 51, 'open': 51, 'maids': 51, 'shoulder': 51, 'sitting': 50, 'shirt': 50, 'destruction': 50, 'flying': 50, 'shouted': 50, 'getting': 50, 'argos': 50, 'presents': 50, 'quite': 50, 'giving': 50, 'something': 50, 'thetis': 49, 'driven': 49, 'bad': 49, 'waves': 49, 'die': 49, 'chest': 49, 'field': 49, 'outside': 49, 'beside': 49, 'sarpedon': 49, 'cloud': 48, 'listen': 48, 'assembly': 48, 'try': 48, 'dawn': 48, 'nine': 48, 'thing': 48, 'speed': 48, 'dinner': 48, 'mercury': 48, 'bearing': 48, 'excellent': 48, 'lest': 48, 'victory': 48, 'grief': 47, 'grant': 47, 'tents': 47, 'seeing': 47, 'telamon': 47, 'large': 47, 'cup': 47, 'afraid': 47, 'bones': 47, 'cloak': 47, 'alexandrus': 47, 'ida': 47, 'wish': 47, 'forthwith': 46, 'trying': 46, 'chariots': 46, 'door': 46, 'course': 46, 'living': 46, 'fellow': 46, 'pieces': 46, 'able': 46, 'broke': 46, 'crew': 46, 'charge': 45, 'carry': 45, 'ere': 45, 'ran': 45, 'anything': 45, 'built': 45, 'iron': 45, 'wild': 45, 'offerings': 45, 'meet': 45, 'princes': 45, 'venus': 45, 'achaean': 45, 'clean': 45, 'clothes': 45, 'prize': 45, 'flung': 44, 'hair': 44, 'cave': 44, 'beneath': 44, 'years': 44, 'sight': 44, 'wives': 44, 'attack': 44, 'since': 44, 'circe': 44, 'prayer': 43, 'wept': 43, 'fate': 43, 'supper': 43, 'run': 43, 'passed': 43, 'fat': 43, 'arrows': 43, 'single': 43, 'goats': 43, 'gifts': 43, 'bread': 43, 'aloud': 42, 'trench': 42, 'cruel': 42, 'parents': 42, 'truth': 42, 'places': 42, 'chief': 42, 'steeds': 42, 'twenty': 41, 'due': 41, 'lies': 41, 'stream': 41, 'terrible': 41, 'cloister': 41, 'running': 41, 'wood': 41, 'offering': 41, 'table': 41, 'talking': 41, 'myrmidons': 40, 'bitterly': 40, 'iris': 40, 'beyond': 40, 'dare': 40, 'heavily': 40, 'rather': 40, 'cover': 40, 'wash': 40, 'washed': 40, 'winds': 40, 'minded': 40, 'low': 39, 'love': 39, 'cunning': 39, 'mischief': 39, 'vain': 39, 'ten': 39, 'horse': 39, 'answer': 39, 'year': 39, 'phoebus': 39, 'stronger': 39, 'spring': 39, 'alas': 38, 'daughters': 38, 'lovely': 38, 'throughout': 38, 'rock': 38, 'pity': 38, 'lived': 38, 'offer': 38, 'standing': 38, 'spite': 38, 'courage': 38, 'ransom': 38, 'sped': 38, 'learn': 37, 'lifted': 37, 'council': 37, 'main': 37, 'furious': 37, 'hardly': 37, 'spoken': 37, 'wait': 37, 'walls': 37, 'doors': 37, 'white': 37, 'queen': 37, 'seats': 37, 'marry': 37, 'leaving': 37, 'rang': 37, 'rage': 37, 'girl': 37, 'teucer': 37, 'aimed': 36, 'black': 36, 'sweet': 36, 'skin': 36, 'sound': 36, 'string': 36, 'blessed': 36, 'met': 36, 'throw': 36, 'boar': 36, 'eating': 36, 'outer': 36, 'flight': 36, 'reins': 36, 'shields': 36, 'lycians': 36, 'huge': 35, 'dwell': 35, 'need': 35, 'arm': 35, 'flesh': 35, 'age': 35, 'captain': 35, 'whereas': 35, 'hereafter': 35, 'tree': 35, 'mules': 35, 'hearts': 35, 'driving': 35, 'race': 35, 'next': 35, 'aim': 35, 'poured': 34, 'become': 34, 'oceanus': 34, 'protect': 34, 'wealth': 34, 'breast': 34, 'saved': 34, 'four': 34, 'story': 34, 'furiously': 34, 'suffered': 34, 'manner': 34, 'pigs': 34, 'handed': 34, 'alike': 34, 'orders': 34, 'calypso': 34, 'menoetius': 33, 'lives': 33, 'gleaming': 33, 'heavy': 33, 'meal': 33, 'wicked': 33, 'voyage': 33, 'mean': 33, 'nurse': 33, 'eurycl ...
